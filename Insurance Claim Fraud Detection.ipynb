# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv')
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.size
# Out:
# 40000

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df=df.drop('_c39',axis=1)
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.incident_date.unique
# Out:
# <bound method Series.unique of 0      25-01-2015
# 1      21-01-2015
# 2      22-02-2015
# 3      10-01-2015
# 4      17-02-2015
#           ...
# 995    22-02-2015
# 996    24-01-2015
# 997    23-01-2015
# 998    26-02-2015
# 999    26-02-2015
# Name: incident_date, Length: 1000, dtype: object>

# %%
df.policy_bind_date.unique
# Out:
# <bound method Series.unique of 0      17-10-2014
# 1      27-06-2006
# 2      06-09-2000
# 3      25-05-1990
# 4      06-06-2014
#           ...
# 995    16-07-1991
# 996    05-01-2014
# 997    17-02-2003
# 998    18-11-2011
# 999    11-11-1996
# Name: policy_bind_date, Length: 1000, dtype: object>

# %%
df.police_report_available.unique
# Out:
# <bound method Series.unique of 0      YES
# 1        ?
# 2       NO
# 3       NO
# 4       NO
#       ...
# 995      ?
# 996      ?
# 997    YES
# 998    YES
# 999      ?
# Name: police_report_available, Length: 1000, dtype: object>

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
df1=lb.fit_transform(df['policy_bind_date'])
pd.Series(df1)
# Out:
# 0      532
# 1      821
# 2      186
# 3      766
# 4      181
#       ...
# 995    487
# 996    129
# 997    509
# 998    573
# 999    359
# Length: 1000, dtype: int32

# %%
df['policy_bind_date']=df1

# %%
df2=lb.fit_transform(df['policy_state'])
pd.Series(df2)
# Out:
# 0      2
# 1      1
# 2      2
# 3      0
# 4      0
#       ..
# 995    2
# 996    0
# 997    2
# 998    0
# 999    2
# Length: 1000, dtype: int32

# %%
df['policy_state']=df2

# %%
df3=lb.fit_transform(df['policy_csl'])
pd.Series(df3)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      2
#       ..
# 995    2
# 996    0
# 997    1
# 998    2
# 999    1
# Length: 1000, dtype: int64

# %%
df['policy_csl']=df3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   int32
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   int32
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
dummy = pd.get_dummies(df[['insured_sex', 'insured_education_level', 'insured_occupation','insured_hobbies','insured_relationship','incident_type','collision_type','incident_date','incident_severity','authorities_contacted','incident_state','incident_city','incident_location','property_damage','police_report_available','auto_make','auto_model','fraud_reported']], drop_first=True)
df = pd.concat([df, dummy], axis=1)

# %%
df= df.drop(['insured_sex', 'insured_education_level', 'insured_occupation','insured_hobbies','insured_relationship','incident_type','incident_date','collision_type','incident_severity','authorities_contacted','incident_state','incident_city','incident_location','property_damage','police_report_available','auto_make','auto_model','fraud_reported'] ,1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\PANKAJ~1\AppData\Local\Temp/ipykernel_18960/524462448.py in <module>
# ----> 1 df= df.drop(['insured_sex', 'insured_education_level', 'insured_occupation','insured_hobbies','insured_relationship','incident_type','incident_date','collision_type','incident_severity','authorities_contacted','incident_state','incident_city','incident_location','property_damage','police_report_available','auto_make','auto_model','fraud_reported'] ,1)
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585                 1             2
# 1                   228   42         342868                 1             1
# 2                   134   29         687698                 0             2
# 3                   256   41         227811                 1             0
# 4                   228   44         367455                 2             0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851                 2             2
# 996                 285   41         186934                 0             0
# 997                 130   34         918516                 1             2
# 998                 458   62         533940                 2             0
# 999                 456   60         556080                 1             2
#
# ...

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_bind_date  \
# count         1000.000000  1000.000000    1000.000000       1000.000000
# mean           203.954000    38.948000  546238.648000          0.951000
# std            115.113174     9.140287  257063.005276          0.804516
# min              0.000000    19.000000  100804.000000          0.000000
# 25%            115.750000    32.000000  335980.250000          0.000000
# 50%            199.500000    38.000000  533135.000000          1.000000
# 75%            276.250000    44.000000  759099.750000          2.000000
# max            479.000000    64.000000  999435.000000          2.000000
#
#        policy_state   policy_csl  policy_deductable  policy_annual_premium  \
# count    1000.00000  1000.000000        1000.000000            1000.000000
# mean        1.01400     0.951000        1136.000000            1256.406150
# std         0.83096     0.804516         611.864673             244.167395
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Columns: 3570 entries, months_as_customer to fraud_reported_Y
# dtypes: float64(1), int32(2), int64(18), uint8(3549)
# memory usage: 3.5 MB

# %%
df.isnull().sum()
# Out:
# months_as_customer     0
# age                    0
# policy_number          0
# policy_bind_date       0
# policy_state           0
#                       ..
# auto_model_Ultima      0
# auto_model_Wrangler    0
# auto_model_X5          0
# auto_model_X6          0
# fraud_reported_Y       0
# Length: 3570, dtype: int64

# %%
X=df.drop(columns=['fraud_reported_Y'])
y=df['fraud_reported_Y']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=348)
y_train.head()
# Out:
#      fraud_reported_Y  fraud_reported_Y  fraud_reported_Y
# 854                 0                 0                 0
# 308                 0                 0                 0
# 274                 0                 0                 0
# 817                 1                 1                 1
# 467                 0                 0                 0

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X,y)
# Out:
# LinearRegression()

# %%
regression.score(X_train,y_train)
regression.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

# %%
model=[DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor()]
max_r2_score=0
for r_state in range(50,90):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=r_state)
    for i in model:
        i.fit(X_train,y_train)
        pred=i.predict(X_test)
        r2_sc=r2_score(y_test,pred)
        print('R2 score',r_state,'is',r2_sc)
        if r2_sc>max_r2_score:
            max_r2_score=r2_sc
            final_state=r_state
            final_model=i
print()
print()
print()
print()
print('Max r2 score',final_state,'is',max_r2_score,"model is",final_model)

# %%
def metric_score(clf,Xc_train,Xc_test,yc_train,yc_test,train=True):
    if train:
        yc_pred=clf.predict(Xc_train)
        print('\n===============Train Result================')
        print(f'Accuracy Score:{accuracy_score(yc_train,yc_pred)*100:.2f}%')
   
    elif train==False:    
        pred=clf.predict(Xc_test)
        print('\n===============Test Result================')
        print(f'Accuracy Score:{accuracy_score(y_test,pred)*100:.2f}%')
        
        print('\n \n Test classification report \n',classification_report(yc_test,pred,digits=2))
